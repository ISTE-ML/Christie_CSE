# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
IMDB=pd.read_csv("imdb (1000 movies) in june 2022.csv")
IMDB
# Out:
#     ranking of movie\r\n                                 movie name\r\n  \
# 0                      1                       The Shawshank Redemption
# 1                      2                                  The Godfather
# 2                      3                                The Dark Knight
# 3                      4  The Lord of the Rings: The Return of the King
# 4                      5                               Schindler's List
# ..                   ...                                            ...
# 995                  996                                        Sabrina
# 996                  997                          From Here to Eternity
# 997                  998                Snow White and the Seven Dwarfs
# 998                  999                                   The 39 Steps
# 999             1,000.00                              The Invisible Man
#
#       Year certificate  runtime                         genre  RATING  \
# ...

# %%
sns.displot(x=IMDB.RATING)
graph1=plt.show()

# %%
plt.style.use("seaborn")
rating_count = IMDB['certificate'].value_counts()
labels = ['15','X','12A','U','All','18','PG','12','A','UA 13+','AA','UA','Not Rated','R','Rejected']
plt.pie(rating_count,labels = labels,  startangle = 90, autopct = "%2.2f%%")
plt.tight_layout()
plt.legend()
plt.title("Ratings Type")
plt.show()
# Out:
# <ipython-input-31-2f409fb02c50>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
plt.scatter(x=IMDB.iloc[0:10,1],y=IMDB.RATING[0:10])
plt.xlabel("Movie")
plt.ylabel("Ratings")
plt.tick_params(rotation=90)
plt.show()

# %%
sns.displot(x=IMDB.RATING,hue=IMDB.certificate, kind = "kde")
graph2=plt.show()
# Out:
# <ipython-input-21-82dfbcd4347e>:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(x=IMDB.RATING,hue=IMDB.certificate, kind = "kde")
# <ipython-input-21-82dfbcd4347e>:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(x=IMDB.RATING,hue=IMDB.certificate, kind = "kde")
